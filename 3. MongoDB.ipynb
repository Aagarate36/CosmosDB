# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
COSMOS_ENDPOINT ='https://azcdb-aag.documents.azure.com:443/'
COSMOS_KEY = 'd76iY9NylLN0rIyZEQ2dNOnGyZnfPHkAOdJa4MwQwq2ETnFVlO8nOKJ0g1t78aZhLTa0DXrzFHAaACDbOPKzBg=='

DATABASE_NAME = 'Test'
Container_ ='retail'

# %%
CONNECTION_STRING ="mongodb://acdbkaagmongodb:p4qgQQJh8IWBN28SketEjNEPooSC4rmv9GUIfw9T3dp2wLiNuNHD4Xb43eOi7il8qO9085H7rSNOACDbxui2Yw==@acdbkaagmongodb.mongo.cosmos.azure.com:10255/?ssl=true&retrywrites=false&replicaSet=globaldb&maxIdleTimeMS=120000&appName=@acdbkaagmongodb@"

# %%
from pymongo import MongoClient

# %%
client = MongoClient (CONNECTION_STRING)
# Out:
# /tmp/ipykernel_10342/2863638729.py:1: UserWarning: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
#   client = MongoClient (CONNECTION_STRING)

# %%
db = client['Test']

# %%
try:
    collection = db.create_collection("retail")
except:
    collection = db['retail']

# %%
query = {"id":"1"}

# %%
documentos = collection.find (query)

# %%
for doc in documentos:
	print (doc)
# Out:
# {'_id': ObjectId('67072ca3f683c6075c58a75c'), 'id': '1', 'nombre': 'Producto A', 'descripcion': 'Descripcion del producto A', 'precio': 29.99, 'categoria': 'Electronica'}

# %%
query = {"categoria": "Accesorios"}

documentos = collection.find (query)

# %%
for doc in documentos:
	print (doc)
# Out:
# {'_id': ObjectId('67072d2cf683c6075c58a75d'), 'id': 'producto_2', 'nombre': 'Producto 2', 'descripcion': 'Descripcion del producto A', 'precio': 22, 'categoria': 'Accesorios'}
# {'_id': ObjectId('67072d2cf683c6075c58a75e'), 'id': 'producto_3', 'nombre': 'Producto 3', 'descripcion': 'Descripcion del producto A', 'precio': 23, 'categoria': 'Accesorios'}
# {'_id': ObjectId('67072d2cf683c6075c58a75f'), 'id': 'producto_4', 'nombre': 'Producto 4', 'descripcion': 'Descripcion del producto A', 'precio': 24, 'categoria': 'Accesorios'}
# {'_id': ObjectId('67072d2cf683c6075c58a760'), 'id': 'producto_5', 'nombre': 'Producto 5', 'descripcion': 'Descripcion del producto A', 'precio': 25, 'categoria': 'Accesorios'}
# {'_id': ObjectId('67072d2cf683c6075c58a761'), 'id': 'producto_6', 'nombre': 'Producto 6', 'descripcion': 'Descripcion del producto A', 'precio': 26, 'categoria': 'Accesorios'}
# ...

# %%
query = {"id":"1"}

# %%
nuevo_valor = {"$set": {"precio": 25}}

# %%
resultado =collection.update_one(query,nuevo_valor)

# %%
query = {"id":"producto_9"}

# %%
resultado = collection.delete_one (query)
